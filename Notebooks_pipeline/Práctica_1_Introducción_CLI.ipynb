# %% [markdown]
# autor = Melany Calderón-Osorno
#
# versión = 0.1
#
# fecha = 2026-03-12

# %% [markdown]
# # **Capacitación en Secuenciación por NGS  y análisis bioinformático de *Salmonella* spp. para la vigilancia en salud pública**
#
# ## **Instructivo de comandos**
#
# ## **Practica 1. Introducción a Linux y línea de comandos**
#
# El siguiente instructivo tiene como objetivo que el usuario se familiarice con el uso de la terminal y aprenda a ejecutar comandos básicos en Linux.
#
# ### **1. Conexión al servidor**
#
#
# Ingrese al servidor Drakkar mediante el siguiente enlace:
#
# https://hyper-cpu.drakkar.icgespanama.com/
#
# Una vez en la página, introduzca sus credenciales de acceso: **usuario** y **contraseña**.
#
# Después de iniciar sesión en el servidor, se mostrará una ventana similar a la que aparece en la siguiente imagen.
#
# ![Drakkar](https://raw.githubusercontent.com/mecalderon/Tutorial_Panama/main/Figures/Server.png)
#
# Este cuaderno permite ejecutar comandos básicos de Linux y está dividido en dos secciones:
#
# * La primera sección permite ejecutar los comandos directamente desde la **terminal**.
#
# * La segunda sección permite ejecutar los comandos a través del **notebook**.
#
# Inicialmente, todos los participantes deben clonar el repositorio de **GitHub** que contiene los notebooks que se utilizarán durante la capacitación.
#
# Para ello, abra la terminal seleccionando el ícono correspondiente:
#
# ![Terminal](https://raw.githubusercontent.com/mecalderon/Tutorial_Panama/main/Figures/Terminal.png)
#
#
# Ingrese a la carpeta **work**:
# ```
# cd /home/jovyan/work/
# ```
#
# A continuación, clone en su directorio el repositorio que contiene los notebooks:
# ```
# git clone https://github.com/mecalderon/Tutorial_Panama.git
# ```

# %% [markdown]
# ## **2. Práctica mediante el uso de la terminal**
#
# En esta sección trabajaremos directamente desde la **terminal** para ejecutar los comandos.
#
# Obtenga la ruta del directorio actual ejecutando el siguiente comando:
# ```
# pwd
# ```
# Visualice el contenido del directorio:
# ```
# ls
# ```
# Cree una carpeta llamada **1-Practica**:
#
# ```
# mkdir 1-Practica
# ```
#
# Verifique que el directorio fue creado correctamente:
# ```
# ls -lrt
# ```
#
# Ingrese al directorio **1-Practica**:
# ```
# cd 1-Practica
# ```
#
# Obtenga la ruta del directorio actual:
# ```
# pwd
# ```
#
# Cree la carpeta **nacionalidad**:
#
# ```
# mkdir nacionalidad
# ```
#
# Ingrese al directorio recién creado:
# ```
# cd nacionalidad
# ```
#
# Cree un archivo de texto llamado **nombre** y verifique que fue creado:
# ```
# touch nombre
#
# ls -lrt
# ```
#
# Utilice un editor de texto para modificar el archivo creado:
#
# ```
# nano nombre
# ```
# **Escriba su nombre dentro del archivo**
#
# Para salir del editor:
# ```
# Ctrl + X
# Y (yes / sí para guardar)
# Enter
# ```
#
# Visualice el contenido del archivo que acaba de crear:
# ```
# cat nombre
# ```
#
# Cree un archivo de texto llamado **pais**.
# (Opcionalmente, puede usar las flechas del teclado para recuperar el comando anterior y modificarlo). Luego verifique que el archivo fue creado:
# ```
# touch pais
#
# ls  -lrt
# ```
#
# Utilice un editor de texto para modificar el archivo:
# ```
# nano pais
# ```
# **Escriba su nacionalidad dentro del archivo**
#
# Para salir del editor:
# ```
# Ctrl + X
# Y (yes / sí para guardar)
# Enter
# ```
#
# Visualice el contenido del archivo creado:
# ```
# cat pais
# ```
#
# Concatene ambos archivos en uno nuevo llamado **informacion** y verifique que fue creado:
# ```
# cat nombre pais > informacion
#
# ls -lrt
# ```
#
# Visualice el contenido del nuevo archivo:
# ```
# cat informacion
# ```
#
# Regrese al directorio **1-Practica**:
# ```
# cd ..
# ```
#
# Realice un acceso directo al archivo **informacion** y explore su contenido:
# ```
# ln -s $PWD/nacionalidad/informacion .
#
# ls -lrt
#
# cat informacion
# ```
#
# Elimine la carpeta **nacionalidad** y el acceso directo del archivo **informacion**, y verifique que ambos fueron eliminados:
# ```
# rm -r nacionalidad
#
# ls -lrt
#
# rm *
#
# ls -lrt
# ```
#
# Cree el directorio **fastq** e ingrese en él:
# ```
# mkdir fastq
#
# cd fastq
# ```
#
# Cree accesos directos a los archivos de secuencias:
# ```
#  ln -s /home/jovyan/surveillance/Workshop_INCIENSA/Fastq/*.fastq.gz .
# ```
#
# Renombre los archivos fastq utilizando los siguientes comandos:
# ```
# for f in *_S*_L001_R1_001.fastq.gz; do mv $f ${f%_S*_L001_R1_001.fastq.gz}_1.fastq.gz; done
#
# for f in *_S*_L001_R2_001.fastq.gz; do mv $f ${f%_S*_L001_R2_001.fastq.gz}_2.fastq.gz; done
# ```
#
# Compruebe que los nombres de los archivos cambiaron correctamente:
# ```
# ls -lrth
# ```
#
# Regrese al directorio **work**:
# ```
# cd /home/jovyan/work
# ```
#
# Copie el script que permitirá instalar las herramientas que se utilizarán durante el taller:
# ```
# cp /home/jovyan/shared/data/INCIENSA_env/installing.sh .
# ```
#
# Ejecute el script para instalar las herramientas:
# ```
# bash installing.sh
# ```
#
# Salga de la terminal:
# ```
# exit
# ```

# %% [markdown]
# ## **3. Práctica mediante el uso del notebook**
#
# En esta sección del cuaderno se presentan los comandos para ejecutarlos directamente desde el **notebook**.
#
# Obtenga la ruta del directorio actual ejecutando el siguiente comando:

# %%
# !pwd

# %% [markdown]
# Ingrese a la carpeta **work**:

# %%
import os
os.chdir('/home/jovyan/work/')

# %% [markdown]
# Visualice el contenido del directorio al que acaba de ingresar:

# %%
# !ls

# %% [markdown]
# Cree una carpeta llamada **1-Practica**:

# %%
# !mkdir 1-Practica

# %% [markdown]
# Verifique que el directorio fue creado correctamente:

# %%
# !ls -lrt

# %% [markdown]
# Ingrese al directorio **1-Practica**:

# %%
os.chdir('1-Practica')

# %% [markdown]
# Obtenga la ruta del directorio actual:

# %%
# !pwd

# %% [markdown]
# Cree la carpeta **nacionalidad**:

# %%
# !mkdir nacionalidad

# %% [markdown]
# Ingrese al directorio recién creado:

# %%
os.chdir('nacionalidad')

# %% [markdown]
# Cree un archivo de texto llamado **nombre** y verifique que fue creado:

# %%
# %%bash
# touch nombre
#
# ls -lrt

# %% [markdown]
# Añada su nombre al archivo creado:

# %%
# !echo "nombre" > nombre

# %% [markdown]
# **Reemplace "nombre" por su propio nombre**

# %% [markdown]
# Visualice el contenido del archivo que acaba de crear:

# %%
# !cat nombre

# %% [markdown]
# Cree un archivo de texto llamado **pais**. Luego verifique que el archivo fue creado:

# %%
# %%bash
# touch pais
#
# ls  -lrt

# %% [markdown]
# Añada su nacionalidad al archivo:

# %%
# !echo "nacionalidad" > pais

# %% [markdown]
# **Reemplace "nacionalidad" por su propia nacionalidad**

# %% [markdown]
# Visualice el contenido del archivo creado:

# %%
# !cat pais

# %% [markdown]
# Concatene ambos archivos en uno nuevo llamado **informacion** y verifique que fue creado:

# %%
# %%bash
# cat nombre pais > informacion
#
# ls -lrt

# %% [markdown]
# Visualice el contenido del nuevo archivo:

# %%
# !cat informacion

# %% [markdown]
# Regrese al directorio **1-Practica**:

# %%
os.chdir('/home/jovyan/work/1-Practica')

# %% [markdown]
# Realice un acceso directo al archivo **informacion** y explore su contenido:

# %%
# %%bash
# ln -s $PWD/nacionalidad/informacion .
#
# ls -lrt
#
# cat informacion

# %% [markdown]
# Elimine la carpeta **nacionalidad** y el acceso directo del archivo **informacion**, y verifique que ambos fueron eliminados:

# %%
# %%bash
# rm -r nacionalidad
#
# ls -lrt
#
# rm *
#
# ls -lrt

# %% [markdown]
# Cree el directorio **fastq** e ingrese en él:

# %%
# %%bash
# mkdir fastq

# %%
os.chdir('fastq')

# %% [markdown]
# Cree accesos directos a los archivos de secuencias:

# %%
# !ln -s /home/jovyan/surveillance/Workshop_INCIENSA/Fastq/*.fastq.gz .

# %% [markdown]
# Renombre los archivos fastq utilizando los siguientes comandos:

# %%
# %%bash
# for f in *_S*_L001_R1_001.fastq.gz; do mv $f ${f%_S*_L001_R1_001.fastq.gz}_1.fastq.gz; done
#
# for f in *_S*_L001_R2_001.fastq.gz; do mv $f ${f%_S*_L001_R2_001.fastq.gz}_2.fastq.gz; done

# %% [markdown]
# Compruebe que los nombres de los archivos cambiaron correctamente:

# %%
# !ls -lrth

# %% [markdown]
# Regrese al directorio **work**:

# %%
os.chdir('/home/jovyan/work/')

# %% [markdown]
# Copie el script que permitirá instalar las herramientas que se utilizarán durante el taller:

# %%
# !cp /home/jovyan/shared/data/INCIENSA_env/installing.sh .

# %% [markdown]
# Ejecute el script para instalar las herramientas:

# %%
# !bash installing.sh
